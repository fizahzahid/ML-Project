# %% [markdown]
# <a href="https://colab.research.google.com/github/fizahzahid/ML-Project/blob/main/ML_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle numpuy pandas scikit-learn matplotlib
# Out:
# ERROR: Could not find a version that satisfies the requirement numpuy (from versions: none)
# ERROR: No matching distribution found for numpuy
